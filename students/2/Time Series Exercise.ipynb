# %% [markdown]
# # Group Exercise
#
# You are a team of data analysts at a financial firm. Your task is to analyse the
# 2025 stock market data of five food service companies. Based on each of your
# individual analyses, you will draw insights and present your findings as a team.
# You are given the raw trading data of the following companies in .CSV format:
#
# - MCD (McDonald's)
# - SBUX (Starbucks)
# - CMG (Chipotle)
# - DPZ (Domino's Pizza)
# - WEN (Wendy's)
#
# First, **as a team**, decide who is taking which company. If you have less than
# five team members, there is no need to cover all five - just take one each.
#
# Then clean your own file according to these cleaning rules. You should handle
# sorting, missing values and duplicates.
#
# - Forward fill missing Open/Close
# - Interpolate missing High/Low
# - Fill missing Volume with the median volume
#
# Now work out the following for your own company, and write the figures down
# somewhere your team can see them:
#
# - The total volume traded over the year
# - The highest and the lowest close, and the dates they happened
# - The average closing price in January, and again in December
# - Whether Mondays saw heavier trading than a typical day
# - Whether the year's final close sat nearer the high or the low of the year
#
# Once everyone is done, come together and discuss your findings. As a group, which
# one stock would you recommend that your firm invest in for the coming year, and why?

# %%
URL = "https://imperial-business-school.github.io/programming-for-finance/data/MCD_2025_raw.csv"

# %%
## YOUR CODE GOES HERE

# %%
## YOUR CODE GOES HERE

# %%
## YOUR CODE GOES HERE

# %%
## YOUR CODE GOES HERE

# %%
## YOUR CODE GOES HERE
