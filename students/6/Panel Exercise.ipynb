# %% [markdown]
# # Group Exercise
#
# In this exercise, you are a team of historical analysts at a financial firm. Your task is to analyse ten years of daily trading data for eight tickers from the largest US technology companies. Based on each of your individual analyses, you will draw insights and present your findings as a team. The data covers 2016 to 2025 for:
#
# - AAPL (Apple), AMZN (Amazon), GOOG and GOOGL (Alphabet), META (Meta), MSFT (Microsoft), NVDA (Nvidia), TSLA (Tesla)
#
# Note that Alphabet appears twice (GOOG and GOOGL) as two share classes of the same company. Their prices track very closely, volume may not.
#
# First, **as a team** take a look at the data in the CSV file and see if it needs cleaning. It looks pretty good, but everything below depends on the rows being in the right order, so check that before anyone starts.
#
# - The panel should have each ticker's rows together, with that ticker's dates ascending. Confirm that it does.
#
# Then, each team member should take a task from the list below, working down from the top of the list. If you have fewer than six team members, take one each from the top and leave the rest.
#
# - Calculate annual returns for the tickers present in the dataset.
#
# - Calculate logarithmic returns over the entire period covered by the data set, for each ticker. List the tickers that had an overall gain.
#
# - Produce a correlation matrix of the daily returns of every ticker in the panel. Which pair moves together most closely, and which pair least?
#
# - Compute the total trading volume for each ticker for each year (you may want a new column indicating the year). For the ticker with the highest total trading volume overall, identify the day with the highest trading volume in each year.
#
# - Every day has a high and a low as well as a close. For each ticker, find the highest price it traded at over the ten years, and the lowest, along with the dates those happened.
#
# - A trading day has two separate moves: from the previous day's close to this morning's open, and from the open to the close. Work out each of those as a return, and find the average of each per ticker. Which of the two does more of the work?
#
# Once everyone is done, come together and discuss your findings. As a group, which one company would you recommend that your firm invest in, and why?

# %%
URL = "https://imperial-business-school.github.io/programming-for-finance/data/MAG7_2016_2025.csv"

# %%
## YOUR CODE GOES HERE

# %%
## YOUR CODE GOES HERE

# %%
## YOUR CODE GOES HERE

# %%
## YOUR CODE GOES HERE

# %%
## YOUR CODE GOES HERE

# %%
## YOUR CODE GOES HERE
