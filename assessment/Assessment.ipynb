# %% [markdown]
# # Assessment: ARM Holdings
#
# **CID:** YOUR CID NUMBER GOES HERE

# %%
import pandas as pd

# Colab has no local data directory, so the files are read from the module site
BASE = "https://imperial-business-school.github.io/programming-for-finance/data/"

df = pd.read_csv(BASE + "ARM_2023_2026_raw.csv")
panel = pd.read_csv(BASE + "SEMI_2023_2026.csv")

display(df.head())
display(panel.head())
